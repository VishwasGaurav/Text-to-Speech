# %%
# !pip install pyttsx3
# Out:
# Requirement already satisfied: pyttsx3 in c:\users\vishwas gaurav\anaconda3\lib\site-packages (2.99)
# Requirement already satisfied: comtypes in c:\users\vishwas gaurav\anaconda3\lib\site-packages (from pyttsx3) (1.4.13)
# Requirement already satisfied: pypiwin32 in c:\users\vishwas gaurav\anaconda3\lib\site-packages (from pyttsx3) (223)
# Requirement already satisfied: pywin32 in c:\users\vishwas gaurav\anaconda3\lib\site-packages (from pyttsx3) (308)

# %%
import pyttsx3

# %%
speaker = pyttsx3.init()
speaker.say("GOOD MORNING EVERYONE")
speaker.runAndWait()

# %%
#SPEAK TO TEXT

# %%
pip install SpeechRecognition

# %%
pip install PyAudio

# %%
import speech_recognition as sr

# %%
mic = sr.Recognizer()

# %%
with sr.Microphone() as source:
    print("start speaking.....")
    voice = mic.listen(source)
    text = mic.recognize_google(voice)
    print("you said this:", text)
